# %%
from urllib.request import urlopen, Request
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = 'https://spaceflightnow.com/launch-log/'
req = Request(url=reg_url, headers=headers) 
html = urlopen(req).read() 
print(html)
# Out:
# b'<!DOCTYPE html>\n<html class="no-js mh-one-sb" lang="en-US">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="profile" href="http://gmpg.org/xfn/11" />\n<link rel="pingback" href="https://spaceflightnow.com/xmlrpc.php" />\n\n<!--Plugin Global Hide Admin Tool Bar Active-->\n\n<!-- This website is patched against a big problem not solved from WordPress 3.3+ to date -->\n\n<title>Launch Log &#8211; Spaceflight Now</title>\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Spaceflight Now &raquo; Feed" href="https://spaceflightnow.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Spaceflight Now &raquo; Comments Feed" href="https://spaceflightnow.com/comments/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/spaceflightnow.com\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.7.2"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n\t\t<style type="text/css">\nimg.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 .07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}\n</style>\n\t<link rel=\'stylesheet\' id=\'wp-block-library-css\'  href=\'https://mk0spaceflightnoa02a.kinstacdn.com/wp-includes/css/dist/block-library/style.min.css?ver=5.7.2\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'mh-magazine-css\'  href=\'https://mk0spaceflightnoa02a.kinstacdn.com/wp-content/themes/mh-magazine/style.css?ver=5.7.2\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'mh-magazine-child-css\'  href=\'https://mk0spaceflightnoa02a.kinstacdn.com/wp-content/th ...

# %%
html_str = str(html)
html_str = html_str[html_str.index('<div class="entry-content clearfix">') + 1:]
html_str = html_str[html_str.index('<div class="datename">'):]
html_str = html_str[:html_str.index('</article>'):]
html_list = []

while ('<div class="datename">' in html_str):
    html_str = html_str[html_str.index('<div class="datename">') + len('<div class="datename">'):]
    if '<div class="datename">' in html_str:
        html_list.append(html_str[:html_str.index('<div class="datename">')])
    else:
        html_list.append(html_str)

# %%
def getInfo(item, tag1, tag2):
    return item[item.index(tag1) + len(tag1): item.index(tag1) + item[item.index(tag1):].index(tag2)]

item = html_list[1]
date = getInfo(item, '<span class="launchdate">', '</span>')
time = getInfo(item, 'Launch time:</span>', '<span class="strong">')
mission = getInfo(item, '<span class="mission">', '</span>')
launchsite = getInfo(item, 'Launch site:</span>', '</div>')
description = getInfo(item, '<div class="missdescrip">', '</div>')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/q7/yjkz42nd3jz_gn9kgn3fhkmc0000gn/T/ipykernel_7424/3366429800.py in <module>
#       4 item = html_list[1]
#       5 date = getInfo(item, '<span class="launchdate">', '</span>')
# ----> 6 time = getInfo(item, 'Launch time:</span>', '<span class="strong">')
#       7 mission = getInfo(item, '<span class="mission">', '</span>')
#       8 launchsite = getInfo(item, 'Launch site:</span>', '</div>')
#
# /var/folders/q7/yjkz42nd3jz_gn9kgn3fhkmc0000gn/T/ipykernel_7424/3366429800.py in getInfo(item, tag1, tag2)
#       1 def getInfo(item, tag1, tag2):
# ----> 2     return item[item.index(tag1) + len(tag1): item.index(tag1) + item[item.index(tag1):].index(tag2)]
#       3
#       4 item = html_list[1]
#       5 date = getInfo(item, '<span class="launchdate">', '</span>')
#
# ValueError: substring not found

# %%
item
# Out:
# '<span class="launchdate">Aug. 29, 2021</span><span class="mission">Falcon 9 \\xe2\\x80\\xa2 SpaceX CRS 23</span></div>\\n<div class="missiondata"><span class="strong">Launch time:</span> 0714:49 GMT (3:14:49 a.m. EDT)<span class="strong"><br />\\nLaunch site:</span> LC-39A, Kennedy Space Center, Florida</div>\\n<div class="missdescrip">A SpaceX Falcon 9 rocket launched a Dragon 2 spacecraft on its third cargo resupply mission to the International Space Station. The flight is the 23rd mission by SpaceX conducted under a Commercial Resupply Services contract with NASA. Delayed from Aug. 18. Scrubbed on Aug. 27 by bad weather. Read our <a href="https://spaceflightnow.com/2021/08/29/spacex-launches-resupply-mission-to-international-space-station/">full story</a>. [Aug. 29]</div>\\n'

# %%
date
# Out:
# 'Aug. 29, 2021'

# %%
launchsite
# Out:
# ' LC-39A, Kennedy Space Center, Florida'

# %%
description
# Out:
# 'A SpaceX Falcon 9 rocket launched a Dragon 2 spacecraft on its third cargo resupply mission to the International Space Station. The flight is the 23rd mission by SpaceX conducted under a Commercial Resupply Services contract with NASA. Delayed from Aug. 18. Scrubbed on Aug. 27 by bad weather. Read our <a href="https://spaceflightnow.com/2021/08/29/spacex-launches-resupply-mission-to-international-space-station/">full story</a>. [Aug. 29]'
